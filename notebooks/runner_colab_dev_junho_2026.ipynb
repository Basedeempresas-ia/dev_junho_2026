# %% [markdown]
# # Runner Colab — BDE/RFB dev_junho_2026
#
# Notebook mínimo para preparar o ambiente operacional no Google Colab.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os

REPO_URL = 'https://github.com/Basedeempresas-ia/dev_junho_2026.git'
REPO_DIR = '/content/dev_junho_2026'

if not os.path.exists(REPO_DIR):
    # !git clone {REPO_URL} {REPO_DIR}
else:
    # %cd {REPO_DIR}
    # !git pull --ff-only

# %cd {REPO_DIR}

# %%
# !pip install -r requirements.txt

# %%
from pathlib import Path

BASE_DIR = Path('/content/drive/MyDrive/BDE')
DATA_DIR = Path('/content/drive/MyDrive/BDE/data')
OUTPUTS_DIR = Path('/content/drive/MyDrive/BDE/outputs/dev_junho_2026')

for path in [BASE_DIR, DATA_DIR, OUTPUTS_DIR]:
    path.mkdir(parents=True, exist_ok=True)

print('BASE_DIR:', BASE_DIR)
print('DATA_DIR:', DATA_DIR)
print('OUTPUTS_DIR:', OUTPUTS_DIR)

# %%
# !find . -maxdepth 3 -type f | sort

# %%
print('Ambiente BDE/RFB dev_junho_2026 pronto para uso no Colab.')
